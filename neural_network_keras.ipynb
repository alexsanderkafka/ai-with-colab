# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score, f1_score, recall_score, confusion_matrix
from keras.models import Sequential
from keras.layers import Dense, Dropout

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/Churn_treino.csv", sep=";")
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure   Balance  NumOfProducts  \
# 0          619    France  Female   42       2         0              1
# 1          608     Spain  Female   41       1   8380786              1
# 2          502    France  Female   42       8   1596608              3
# 3          699    France  Female   39       1         0              2
# 4          850     Spain  Female   43       2  12551082              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1         10134888       1
# 1          0               1         11254258       0
# 2          1               0         11393157       1
# 3          0               0          9382663       0
# 4          1               1           790841       0

# %%
x = df.drop("Exited", axis=1)
y = df["Exited"]

# %%
scaler = StandardScaler()
numerical = x.select_dtypes(include=['int64', 'float64']).columns
x[numerical] = scaler.fit_transform(x[numerical])

# %%
x.head()
# Out:
#    CreditScore Geography  Gender       Age    Tenure   Balance  NumOfProducts  \
# 0    -0.326221    France  Female  0.293517 -1.041760 -1.110553      -0.911583
# 1    -0.440036     Spain  Female  0.198164 -1.387538  0.222782      -0.911583
# 2    -1.536794    France  Female  0.293517  1.032908 -0.856542       2.527057
# 3     0.501521    France  Female  0.007457 -1.387538 -1.110553       0.807737
# 4     2.063884     Spain  Female  0.388871 -1.041760  0.886252      -0.911583
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0   0.646092        0.970243         0.170614
# 1  -1.547768        0.970243         0.353281
# 2   0.646092       -1.030670         0.375948
# 3  -1.547768       -1.030670         0.047859
# 4   0.646092        0.970243        -1.354223

# %%
encoder = LabelEncoder()
categorical = x.select_dtypes(include='object').columns

for col in categorical:
  x[col] = encoder.fit_transform(x[col])

# %%
x.head()
# Out:
#    CreditScore  Geography  Gender       Age    Tenure   Balance  \
# 0    -0.326221          0       0  0.293517 -1.041760 -1.110553
# 1    -0.440036          2       0  0.198164 -1.387538  0.222782
# 2    -1.536794          0       0  0.293517  1.032908 -0.856542
# 3     0.501521          0       0  0.007457 -1.387538 -1.110553
# 4     2.063884          2       0  0.388871 -1.041760  0.886252
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 0      -0.911583   0.646092        0.970243         0.170614
# 1      -0.911583  -1.547768        0.970243         0.353281
# 2       2.527057   0.646092       -1.030670         0.375948
# 3       0.807737  -1.547768       -1.030670         0.047859
# 4      -0.911583   0.646092        0.970243        -1.354223

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)

# %%
model = Sequential()
model.add(Dense(units=64, activation='relu', input_dim=x_train.shape[1]))
model.add(Dropout(0.4))
model.add(Dense(units=32, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(units=64, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(units=1, activation='sigmoid'))

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8628 - loss: 0.3355
# Epoch 2/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8702 - loss: 0.3233
# Epoch 3/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8758 - loss: 0.3227
# Epoch 4/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8618 - loss: 0.3370
# Epoch 5/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8684 - loss: 0.3328
# Epoch 6/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8651 - loss: 0.3334
# Epoch 7/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8633 - loss: 0.3353
# Epoch 8/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8700 - loss: 0.3292
# Epoch 9/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8696 - loss: 0.3413
# Epoch 10/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8657 - loss: 0.3278
# Epoch 11/100
# ...

# %%
predicts = model.predict(x_test)
predicts
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# array([[0.2490203 ],
#        [0.259677  ],
#        [0.17224003],
#        ...,
#        [0.06265358],
#        [0.12588051],
#        [0.65337765]], dtype=float32)

# %%
y_predict = (predicts > 0.5).astype('int32')
y_predict
# Out:
# array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [1]], dtype=int32)

# %%
print(f"Acurácia: {accuracy_score(y_test, y_predict)}")
print(f"F1: {f1_score(y_test, y_predict)}")
print(f"Recall: {recall_score(y_test, y_predict)}")
print(f"Matriz de Confusão: {confusion_matrix(y_test, y_predict)}")
# Out:
# Acurácia: 0.8563333333333333
# F1: 0.5843780135004821
# Recall: 0.48792270531400966
# Matriz de Confusão: [[2266  113]
#  [ 318  303]]
